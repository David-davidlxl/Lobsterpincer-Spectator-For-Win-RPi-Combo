# %% [markdown]
# # SqueezeNet1p1 model training
#
# This notebook can be used to train the SqueezeNet1p1 model on Google Colab.
#
# Note: this script is a modified version of the "chess_piece_models_common.py," "squeezenet.py," and "train_squeezenet1p1.py" (in the "cpmodels" folder) of the LiveChess2FEN project (https://github.com/davidmallasen/LiveChess2FEN).

# %% [markdown]
# # Step 1: enable GPU on Google Colab
#
# ### Use the following code to verify that GPU is enabled

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # Step 2: upload the pretrained model
#
# ### Create a "models" folder containing the pretrained SqueezeNet1p1 model "SqueezeNet1p1_old.h5"
#
# ### Compress the "models" folder into "models.zip"
#
# ### Upload "models.zip" to Google Colab
#
# ### Unzip "models.zip" with the following code

# %%
# !unzip models.zip
# Out:
# Archive:  models.zip
#   inflating: models/SqueezeNet1p1_old.h5

# %% [markdown]
# (Feel free to delete the uploaded "models.zip" once it's unzipped)

# %% [markdown]
# # Step 3: import data
#
# ### Create a "data" folder containing the "training" folder and the "validation" folder with each folder containing exactly 13 subfolders ("\_", "r_", "n_", "b_", "q_", "k_", "p_", "R", "N", "B", "Q", "K", and "P")
#
# ### Compress the "data" folder into "data.zip"
#
# ### Upload "data.zip" to Google Colab
#
# ### Unzip the compressed file using the following code

# %%
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/q_/109.jpg
#   inflating: data/train/q_/11.jpg
#   inflating: data/train/q_/110.jpg
#   inflating: data/train/q_/111.jpg
#   inflating: data/train/q_/112.jpg
#   inflating: data/train/q_/113.jpg
#   inflating: data/train/q_/114.jpg
#   inflating: data/train/q_/115.jpg
#   inflating: data/train/q_/116.jpg
#   inflating: data/train/q_/117.jpg
#   inflating: data/train/q_/118.jpg
#   inflating: data/train/q_/119.jpg
#   inflating: data/train/q_/12.jpg
#   inflating: data/train/q_/120.jpg
#   inflating: data/train/q_/121.jpg
#   inflating: data/train/q_/122.jpg
#   inflating: data/train/q_/123.jpg
#   inflating: data/train/q_/124.jpg
#   inflating: data/train/q_/125.jpg
#   inflating: data/train/q_/126.jpg
#   inflating: data/train/q_/127.jpg
#   inflating: data/train/q_/128.jpg
#   inflating: data/train/q_/129.jpg
#   inflating: data/train/q_/13.jpg
#   inflating: data/train/q_/130.jpg
#   inflating: data/train/q_/131.jpg
#   inflating: data/train/q_/132.jpg
#   inflating: data/train/q_/133.jpg
#   inflating: data/train/q_/134.jpg
#   inflating: data/train/q_/135.jpg
#   inflating: data/train/q_/136.jpg
#   inflating: data/train/q_/137.jpg
#   inflating: data/train/q_/138.jpg
#   inflating: data/train/q_/139.jpg
#   inflating: data/train/q_/14.jpg
#   inflating: data/train/q_/140.jpg
#   inflating: data/train/q_/141.jpg
#   inflating: data/train/q_/142.jpg
#   inflating: data/train/q_/143.jpg
#   inflating: data/train/q_/144.jpg
#   inflating: data/train/q_/145.jpg
#   inflating: data/train/q_/146.jpg
#   inflating: data/train/q_/147.jpg
#   inflating: data/train/q_/148.jpg
#   inflating: data/train/q_/149.jpg
#   inflating: data/train/q_/15.jpg
#   inflating: data/train/q_/150.jpg
#   inflating: data/train/q_/151.jpg
#   inflating: data/train/q_/152.jpg
#   inflating: data/validation/R/745.jpg
#   inflating: data/validation/R/746.jpg
#   inflating: data/validation/R/747.jpg
#   inflating: data/validation/R/748.jpg
#   inflating: data/validation/R/749.jpg
#   inflating: data/validation/R/75.jpg
#   inflating: data/validation/R/750.jpg
#   inflating: data/validation/R/751.jpg
#   inflating: data/validation/R/752.jpg
#   inflating: data/validation/R/753.jpg
#   inflating: data/validation/R/754.jpg
#   inflating: data/validation/R/755.jpg
#   inflating: data/validation/R/756.jpg
#   inflating: data/validation/R/757.jpg
#   inflating: data/validation/R/758.jpg
#   inflating: data/validation/R/759.jpg
#   inflating: data/validation/R/76.jpg
#   inflating: data/validation/R/760.jpg
#   inflating: data/validation/R/761.jpg
#   inflating: data/validation/R/762.jpg
#   inflating: data/validation/R/763.jpg
#   inflating: data/validation/R/764.jpg
#   inflating: data/validation/R/765.jpg
#   inflating: data/validation/R/766.jpg
#   inflating: data/validation/R/767.jpg
#   inflating: data/validation/R/768.jpg
#   inflating: data/validation/R/769.jpg
#   inflating: data/validation/R/77.jpg
#   inflating: data/validation/R/770.jpg
#   inflating: data/validation/R/771.jpg
#   inflating: data/validation/R/772.jpg
#   inflating: data/validation/R/773.jpg
#   inflating: data/validation/R/774.jpg
#   inflating: data/validation/R/775.jpg
#   inflating: data/validation/R/776.jpg
#   inflating: data/validation/R/777.jpg
#   inflating: data/validation/R/778.jpg
#   inflating: data/validation/R/779.jpg
#   inflating: data/validation/R/78.jpg
#   inflating: data/validation/R/780.jpg
#   inflating: data/validation/R/781.jpg
#   inflating: data/validation/R/782.jpg
#   inflating: data/validation/R/783.jpg
#   inflating: data/validation/R/784.jpg
#   inflating: data/validation/R/785.jpg
#   inflating: data/validation/R/786.jpg
#   inflating: data/validation/R/787.jpg
#   inflating: data/validation/R/788.jpg
#   inflating: data/validation/R/789.jpg
#   inflating: data/validation/R/79.jpg
#   inflating: data/validation/R/790.jpg
#   inflating: data/validation/R/791.jpg
#   inflating: data/validation/R/792.jpg
#   inflating: data/validation/R/793.jpg
#   inflating: data/validation/R/794.jpg
#   inflating: data/validation/R/795.jpg
#   inflating: data/validation/R/796.jpg
#   inflating: data/validation/R/797.jpg
#   inflating: data/validation/R/798.jpg
#   inflating: data/validation/R/799.jpg
#   inflating: data/validation/R/8.jpg
#   inflating: data/validation/R/80.jpg
#   inflating: data/validation/R/800.jpg
#   inflating: data/validation/R/801.jpg
#   inflating: data/validation/R/802.jpg
#   inflating: data/validation/R/803.jpg
#   inflating: data/validation/R/804.jpg
#   inflating: data/validation/R/805.jpg
#   inflating: data/validation/R/806.jpg
#   inflating: data/validation/R/807.jpg
#   inflating: data/validation/R/808.jpg
#   inflating: data/validation/R/809.jpg
#   inflating: data/validation/R/81.jpg
#   inflating: data/validation/R/810.jpg
#   inflating: data/validation/R/811.jpg
#   inflating: data/validation/R/812.jpg
#   inflating: data/validation/R/813.jpg
#   inflating: data/validation/R/814.jpg
#   inflating: data/validation/R/815.jpg
#   inflating: data/validation/R/816.jpg
#   inflating: data/validation/R/817.jpg
#   inflating: data/validation/R/818.jpg
#   inflating: data/validation/R/819.jpg
#   inflating: data/validation/R/82.jpg
#   inflating: data/validation/R/820.jpg
#   inflating: data/validation/R/821.jpg
#   inflating: data/validation/R/822.jpg
#   inflating: data/validation/R/823.jpg
#   inflating: data/validation/R/824.jpg
#   inflating: data/validation/R/825.jpg
#   inflating: data/validation/R/826.jpg
#   inflating: data/validation/R/827.jpg
#   inflating: data/validation/R/828.jpg
#   inflating: data/validation/R/829.jpg
#   inflating: data/validation/R/83.jpg
#   inflating: data/validation/R/830.jpg
#   inflating: data/validation/R/831.jpg
#   inflating: data/validation/R/832.jpg
#   inflating: data/validation/R/833.jpg
#   inflating: data/validation/R/834.jpg
#   inflating: data/validation/R/835.jpg
#   inflating: data/validation/R/836.jpg
#   inflating: data/validation/R/837.jpg
#   inflating: data/validation/R/838.jpg
#   inflating: data/validation/R/839.jpg
#   inflating: data/validation/R/84.jpg
#   inflating: data/validation/R/840.jpg
#   inflating: data/validation/R/841.jpg
#   inflating: data/validation/R/842.jpg
#   inflating: data/validation/R/843.jpg
#   inflating: data/validation/R/844.jpg
#   inflating: data/validation/R/845.jpg
#   inflating: data/validation/R/846.jpg
#   inflating: data/validation/R/847.jpg
#   inflating: data/validation/R/848.jpg
#   inflating: data/validation/R/849.jpg
#   inflating: data/validation/R/85.jpg
#   inflating: data/validation/R/850.jpg
#   inflating: data/validation/R/851.jpg
#   inflating: data/validation/R/852.jpg
#   inflating: data/validation/R/853.jpg
#   inflating: data/validation/R/854.jpg
#   inflating: data/validation/R/855.jpg
#   inflating: data/validation/R/856.jpg
#   inflating: data/validation/R/857.jpg
#   inflating: data/validation/R/858.jpg
#   inflating: data/validation/R/859.jpg
#   inflating: data/validation/R/86.jpg
#   inflating: data/validation/R/860.jpg
#   inflating: data/validation/R/861.jpg
#   inflating: data/validation/R/862.jpg
#   inflating: data/validation/R/863.jpg
#   inflating: data/validation/R/864.jpg
#   inflating: data/validation/R/865.jpg
#   inflating: data/validation/R/866.jpg
#   inflating: data/validation/R/867.jpg
#   inflating: data/validation/R/868.jpg
#   inflating: data/validation/R/869.jpg
#   inflating: data/validation/R/87.jpg
#   inflating: data/validation/R/870.jpg
#   inflating: data/validation/R/871.jpg
#   inflating: data/validation/R/872.jpg
#   inflating: data/validation/R/873.jpg
#   inflating: data/validation/R/874.jpg
#   inflating: data/validation/R/875.jpg
#   inflating: data/validation/R/876.jpg
#   inflating: data/validation/R/877.jpg
#   inflating: data/validation/R/878.jpg
#   inflating: data/validation/R/879.jpg
#   inflating: data/validation/R/88.jpg
#   inflating: data/validation/R/880.jpg
#   inflating: data/validation/R/881.jpg
#   inflating: data/validation/R/89.jpg
#   inflating: data/validation/R/9.jpg
#   inflating: data/validation/R/90.jpg
#   inflating: data/validation/R/91.jpg
#   inflating: data/validation/R/92.jpg
#   inflating: data/validation/R/93.jpg
#   inflating: data/validation/R/94.jpg
#   inflating: data/validation/R/95.jpg
#   inflating: data/validation/R/96.jpg
#   inflating: data/validation/R/97.jpg
#   inflating: data/validation/R/98.jpg
#   inflating: data/validation/R/99.jpg
#    creating: data/validation/r_/
#   inflating: data/validation/r_/74.jpg
#   inflating: data/validation/r_/740.jpg
#   inflating: data/validation/r_/741.jpg
#   inflating: data/validation/r_/742.jpg
#   inflating: data/validation/r_/743.jpg
#   inflating: data/validation/r_/744.jpg
#   inflating: data/validation/r_/745.jpg
#   inflating: data/validation/r_/746.jpg
#   inflating: data/validation/r_/747.jpg
#   inflating: data/validation/r_/748.jpg
#   inflating: data/validation/r_/749.jpg
#   inflating: data/validation/r_/75.jpg
#   inflating: data/validation/r_/750.jpg
#   inflating: data/validation/r_/751.jpg
#   inflating: data/validation/r_/752.jpg
#   inflating: data/validation/r_/753.jpg
#   inflating: data/validation/r_/754.jpg
#   inflating: data/validation/r_/755.jpg
#   inflating: data/validation/r_/756.jpg
#   inflating: data/validation/r_/757.jpg
#   inflating: data/validation/r_/758.jpg
#   inflating: data/validation/r_/759.jpg
#   inflating: data/validation/r_/76.jpg
#   inflating: data/validation/r_/760.jpg
#   inflating: data/validation/r_/761.jpg
#   inflating: data/validation/r_/762.jpg
#   inflating: data/validation/r_/763.jpg
#   inflating: data/validation/r_/764.jpg
#   inflating: data/validation/r_/765.jpg
#   inflating: data/validation/r_/766.jpg
#   inflating: data/validation/r_/767.jpg
#   inflating: data/validation/r_/768.jpg
#   inflating: data/validation/r_/769.jpg
#   inflating: data/validation/r_/77.jpg
#   inflating: data/validation/r_/770.jpg
#   inflating: data/validation/r_/771.jpg
#   inflating: data/validation/r_/772.jpg
#   inflating: data/validation/r_/773.jpg
#   inflating: data/validation/r_/774.jpg
#   inflating: data/validation/r_/775.jpg
#   inflating: data/validation/r_/776.jpg
#   inflating: data/validation/r_/777.jpg
#   inflating: data/validation/r_/778.jpg
#   inflating: data/validation/r_/779.jpg
#   inflating: data/validation/r_/78.jpg
#   inflating: data/validation/r_/780.jpg
#   inflating: data/validation/r_/781.jpg
#   inflating: data/validation/r_/782.jpg
#   inflating: data/validation/r_/783.jpg
#   inflating: data/validation/r_/784.jpg
#   inflating: data/validation/r_/785.jpg
#   inflating: data/validation/r_/786.jpg
#   inflating: data/validation/r_/787.jpg
#   inflating: data/validation/r_/788.jpg
#   inflating: data/validation/r_/789.jpg
#   inflating: data/validation/r_/79.jpg
#   inflating: data/validation/r_/790.jpg
#   inflating: data/validation/r_/791.jpg
#   inflating: data/validation/r_/792.jpg
#   inflating: data/validation/r_/793.jpg
#   inflating: data/validation/r_/794.jpg
#   inflating: data/validation/r_/795.jpg
#   inflating: data/validation/r_/796.jpg
#   inflating: data/validation/r_/797.jpg
#   inflating: data/validation/r_/798.jpg
#   inflating: data/validation/r_/799.jpg
#   inflating: data/validation/r_/8.jpg
#   inflating: data/validation/r_/80.jpg
#   inflating: data/validation/r_/800.jpg
#   inflating: data/validation/r_/801.jpg
#   inflating: data/validation/r_/802.jpg
#   inflating: data/validation/r_/803.jpg
#   inflating: data/validation/r_/804.jpg
#   inflating: data/validation/r_/805.jpg
#   inflating: data/validation/r_/806.jpg
#   inflating: data/validation/r_/807.jpg
#   inflating: data/validation/r_/808.jpg
#   inflating: data/validation/r_/809.jpg
#   inflating: data/validation/r_/81.jpg
#   inflating: data/validation/r_/810.jpg
#   inflating: data/validation/r_/811.jpg
#   inflating: data/validation/r_/812.jpg
#   inflating: data/validation/r_/813.jpg
#   inflating: data/validation/r_/814.jpg
#   inflating: data/validation/r_/815.jpg
#   inflating: data/validation/r_/816.jpg
#   inflating: data/validation/r_/817.jpg
#   inflating: data/validation/r_/818.jpg
#   inflating: data/validation/r_/819.jpg
#   inflating: data/validation/r_/82.jpg
#   inflating: data/validation/r_/820.jpg
#   inflating: data/validation/r_/821.jpg
#   inflating: data/validation/r_/822.jpg
#   inflating: data/validation/r_/823.jpg
#   inflating: data/validation/r_/824.jpg
#   inflating: data/validation/r_/825.jpg
#   inflating: data/validation/r_/826.jpg
#   inflating: data/validation/r_/827.jpg
#   inflating: data/validation/r_/828.jpg
#   inflating: data/validation/r_/829.jpg
#   inflating: data/validation/r_/83.jpg
#   inflating: data/validation/r_/830.jpg
#   inflating: data/validation/r_/831.jpg
#   inflating: data/validation/r_/832.jpg
#   inflating: data/validation/r_/833.jpg
#   inflating: data/validation/r_/834.jpg
#   inflating: data/validation/r_/835.jpg
#   inflating: data/validation/r_/836.jpg
#   inflating: data/validation/r_/837.jpg
#   inflating: data/validation/r_/838.jpg
#   inflating: data/validation/r_/839.jpg
#   inflating: data/validation/r_/84.jpg
#   inflating: data/validation/r_/840.jpg
#   inflating: data/validation/r_/841.jpg
#   inflating: data/validation/r_/842.jpg
#   inflating: data/validation/r_/843.jpg
#   inflating: data/validation/r_/844.jpg
#   inflating: data/validation/r_/845.jpg
#   inflating: data/validation/r_/846.jpg
#   inflating: data/validation/r_/847.jpg
#   inflating: data/validation/r_/848.jpg
#   inflating: data/validation/r_/849.jpg
#   inflating: data/validation/r_/85.jpg
#   inflating: data/validation/r_/850.jpg
#   inflating: data/validation/r_/851.jpg
#   inflating: data/validation/r_/852.jpg
#   inflating: data/validation/r_/853.jpg
#   inflating: data/validation/r_/854.jpg
#   inflating: data/validation/r_/855.jpg
#   inflating: data/validation/r_/856.jpg
#   inflating: data/validation/r_/857.jpg
#   inflating: data/validation/r_/858.jpg
#   inflating: data/validation/r_/859.jpg
#   inflating: data/validation/r_/86.jpg
#   inflating: data/validation/r_/860.jpg
#   inflating: data/validation/r_/861.jpg
#   inflating: data/validation/r_/862.jpg
#   inflating: data/validation/r_/863.jpg
#   inflating: data/validation/r_/864.jpg
#   inflating: data/validation/r_/865.jpg
#   inflating: data/validation/r_/866.jpg
#   inflating: data/validation/r_/867.jpg
#   inflating: data/validation/r_/868.jpg
#   inflating: data/validation/r_/869.jpg
#   inflating: data/validation/r_/87.jpg
#   inflating: data/validation/r_/870.jpg
#   inflating: data/validation/r_/871.jpg
#   inflating: data/validation/r_/872.jpg
#   inflating: data/validation/r_/873.jpg
#   inflating: data/validation/r_/874.jpg
#   inflating: data/validation/r_/875.jpg
#   inflating: data/validation/r_/876.jpg
#   inflating: data/validation/r_/877.jpg
#   inflating: data/validation/r_/878.jpg
#   inflating: data/validation/r_/879.jpg
#   inflating: data/validation/r_/88.jpg
#   inflating: data/validation/r_/880.jpg
#   inflating: data/validation/r_/881.jpg
#   inflating: data/validation/r_/882.jpg
#   inflating: data/validation/r_/883.jpg
#   inflating: data/validation/r_/884.jpg
#   inflating: data/validation/r_/885.jpg
#   inflating: data/validation/r_/886.jpg
#   inflating: data/validation/r_/887.jpg
#   inflating: data/validation/r_/888.jpg
#   inflating: data/validation/r_/89.jpg
#   inflating: data/validation/r_/9.jpg
#   inflating: data/validation/r_/90.jpg
#   inflating: data/validation/r_/91.jpg
#   inflating: data/validation/r_/92.jpg
#   inflating: data/validation/r_/93.jpg
#   inflating: data/validation/r_/94.jpg
#   inflating: data/validation/r_/95.jpg
#   inflating: data/validation/r_/96.jpg
#   inflating: data/validation/r_/97.jpg
#   inflating: data/validation/r_/98.jpg
#   inflating: data/validation/r_/99.jpg

# %% [markdown]
# ### Rename the train and validation data folders:

# %%
import os
os.rename('./data/train/b_', './data/train/b')
os.rename('./data/train/k_', './data/train/k')
os.rename('./data/train/n_', './data/train/n')
os.rename('./data/train/p_', './data/train/p')
os.rename('./data/train/q_', './data/train/q')
os.rename('./data/train/r_', './data/train/r')

os.rename('./data/validation/b_', './data/validation/b')
os.rename('./data/validation/k_', './data/validation/k')
os.rename('./data/validation/n_', './data/validation/n')
os.rename('./data/validation/p_', './data/validation/p')
os.rename('./data/validation/q_', './data/validation/q')
os.rename('./data/validation/r_', './data/validation/r')

# %% [markdown]
# Notes: 1) to replace the existing data with new data, delete the "data" folder with the following code (uncomment it first) and repeat step 5:

# %%
# import shutil
# shutil.rmtree('./data')

# %% [markdown]
# 2) if there happens to be a (hidden) folder called ".ipynb_checkpoints" in the "train" or "validation" folder, make sure to delete it with the following code (uncomment it first):

# %%
# import shutil
# shutil.rmtree('./data/train/.ipynb_checkpoints')
# shutil.rmtree('./data/validation/.ipynb_checkpoints')

# %% [markdown]
# # Step 6: define common functions

# %%
"""This module has common functions for training chess-piece models."""
import matplotlib

matplotlib.use("agg")
import matplotlib.pyplot as plt

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator


def build_model(base_model: Model) -> Model:
    """Build the model from a pretrained base model.

    :param base_model: Base model from keras applications.

        Example: `MobileNetV2(input_shape=(224, 224, 3),
        include_top=False, weights='imagenet')`.

    :return: The compiled model to train.
    """
    layers = base_model.output
    layers = GlobalAveragePooling2D()(layers)
    layers = Dense(1024, activation="relu")(layers)
    preds = Dense(13, activation="softmax")(layers)

    model = Model(inputs=base_model.input, outputs=preds)

    model.compile(
        optimizer="Adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )

    return model


def data_generators(
    preprocessing_func,
    target_size: tuple[int, int],
    batch_size: int,
    train_path: str = "./data/train/",
    validation_path: str = "./data/validation/",
):
    """Return the train and validation generators.

    :param preprocessing_func: Preprocessing function for base model.

        This is the preprocessing function for the pretrained base
        model.

        Example: `from keras.applications.mobilenet_v2 import
        preprocess_input`.

    :param target_size: Dimensions to which all images will be resized.

        Example: `(224, 224)`.

    :param batch_size: Size of the batches of data.

    :param train_path: Path to the train folder.

    :param validation_path: Path to the validation folder.

    :return: Train and validation generators.
    """
    datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_func, dtype="float16"
    )

    train_gen = datagen.flow_from_directory(
        train_path,
        target_size=target_size,
        color_mode="rgb",
        batch_size=batch_size,
        class_mode="categorical",
        shuffle=True,
    )

    val_gen = datagen.flow_from_directory(
        validation_path,
        target_size=target_size,
        color_mode="rgb",
        batch_size=batch_size,
        class_mode="categorical",
        shuffle=True,
    )
    return train_gen, val_gen


def train_model(
    model: Model,
    epochs: int,
    train_generator,
    val_generator,
    callbacks,
    use_weights: bool,
    workers: int,
    use_multiprocessing,
):
    """Train the input model."""
    steps_per_epoch = train_generator.n // train_generator.batch_size
    validation_steps = val_generator.n // val_generator.batch_size

    if use_weights:
        weights = {
            0: 1.0,
            1: 1.0,
            2: 1.0,
            3: 0.125,
            4: 1.0,
            5: 1.0,
            6: 0.05,
            7: 1.0,
            8: 1.0,
            9: 1.0,
            10: 0.125,
            11: 1.0,
            12: 1.0,
        }
    else:
        weights = None

    return model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        validation_data=val_generator,
        validation_steps=validation_steps,
        callbacks=callbacks,
        verbose=2,
        class_weight=weights,
        use_multiprocessing=use_multiprocessing,
        workers=workers,
    )


def model_callbacks(
    early_stopping_patience: int,
    model_checkpoint_dir,
    reducelr_factor: float,
    reducelr_patience: int,
) -> list:
    """Initialize the model callbacks."""
    early_stopping = EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        verbose=1,
        patience=early_stopping_patience,
        restore_best_weights=True,
        min_delta=0.002,
    )
    model_checkpoint = ModelCheckpoint(
        filepath=model_checkpoint_dir,
        monitor="val_accuracy",
        mode="max",
        verbose=1,
        save_best_only=True,
    )
    reduce_lr = ReduceLROnPlateau(
        monitor="val_accuracy",
        mode="max",
        factor=reducelr_factor,
        patience=reducelr_patience,
        verbose=1,
    )
    return [early_stopping, model_checkpoint, reduce_lr]


def plot_model_history(history, accuracy_savedir, loss_savedir):
    """Plot the model history (accuracy and loss)."""
    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Training accuracy', 'Validation accuracy'])
    plt.grid()
    plt.savefig(accuracy_savedir)
    plt.close()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training loss', 'Validation loss'])
    plt.grid()
    plt.savefig(loss_savedir)
    plt.close()


def evaluate_model(model, test_generator):
    """
    Print the test loss and accuracy of the model.

    :param model: Model to evaluate.

    :param test_generator: Generator with which to test the model.
    """
    scores = model.evaluate(test_generator, verbose=1)
    print("Test loss:", scores[0])
    print("Test accuracy:", scores[1])

# %% [markdown]
# # Step 7: define training functions

# %%
"""This module contains the SqueezeNet-v1.1 implementation."""


import warnings

from keras import backend as K
from keras.utils.layer_utils import get_source_inputs
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.layers import (
    Input,
    Convolution2D,
    MaxPooling2D,
    Activation,
    concatenate,
    Dropout,
)
from keras.models import Model
from keras.utils import get_file
from keras.utils import layer_utils
from keras.applications.imagenet_utils import obtain_input_shape


SQ1X1 = "squeeze1x1"
EXP1X1 = "expand1x1"
EXP3X3 = "expand3x3"
RELU = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_NO_TOP = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels_notop.h5"


def fire_module(x, fire_id, squeeze=16, expand=64):
    """Fire up the module.

    This is the modular function for Fire Node.
    """
    s_id = "fire" + str(fire_id) + "/"

    if K.image_data_format() == "channels_first":
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding="valid", name=s_id + SQ1X1)(x)
    x = Activation("relu", name=s_id + RELU + SQ1X1)(x)

    left = Convolution2D(expand, (1, 1), padding="valid", name=s_id + EXP1X1)(
        x
    )
    left = Activation("relu", name=s_id + RELU + EXP1X1)(left)

    right = Convolution2D(expand, (3, 3), padding="same", name=s_id + EXP3X3)(
        x
    )
    right = Activation("relu", name=s_id + RELU + EXP3X3)(right)

    return concatenate([left, right], axis=channel_axis, name=s_id + "concat")


def SqueezeNet(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
):
    """Instantiate the original SqueezeNet architecture from paper."""
    if weights not in {"imagenet", None}:
        raise ValueError(
            "The `weights` argument should be either "
            "`None` (random initialization) or `imagenet` "
            "(pre-training on ImageNet)."
        )

    if weights == "imagenet" and classes != 1000:
        raise ValueError(
            "If using `weights` as imagenet with `include_top`"
            " as true, `classes` should be 1000"
        )

    input_shape = obtain_input_shape(
        input_shape,
        default_size=227,
        min_size=48,
        data_format=K.image_data_format(),
        require_flatten=include_top,
    )

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    x = Convolution2D(
        64, (3, 3), strides=(2, 2), padding="valid", name="conv1"
    )(img_input)
    x = Activation("relu", name="relu_conv1")(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pool1")(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pool3")(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pool5")(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)

    if include_top:
        # It's not obvious where to cut the network...
        # Could do the 8th or 9th layer... some work recommends cutting
        # earlier layers.

        x = Dropout(0.5, name="drop9")(x)

        x = Convolution2D(classes, (1, 1), padding="valid", name="conv10")(x)
        x = Activation("relu", name="relu_conv10")(x)
        x = GlobalAveragePooling2D()(x)
        x = Activation("softmax", name="loss")(x)
    else:
        if pooling == "avg":
            x = GlobalAveragePooling2D()(x)
        elif pooling == "max":
            x = GlobalMaxPooling2D()(x)
        elif pooling is None:
            pass
        else:
            raise ValueError("Unknown argument for 'pooling'=" + pooling)

    # Ensure that the model takes into account any potential
    # predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    model = Model(inputs, x, name="squeezenet")

    # Load weights
    if weights == "imagenet":
        if include_top:
            weights_path = get_file(
                "squeezenet_weights_tf_dim_ordering_tf_kernels.h5",
                WEIGHTS_PATH,
                cache_subdir="models",
            )
        else:
            weights_path = get_file(
                "squeezenet_weights_tf_dim_ordering_tf_kernels_notop.h5",
                WEIGHTS_PATH_NO_TOP,
                cache_subdir="models",
            )

        model.load_weights(weights_path)
        if K.backend() == "theano":
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == "channels_first":
            if K.backend() == "tensorflow":
                warnings.warn(
                    "You are using the TensorFlow backend, yet you "
                    "are using the Theano "
                    "image data format convention "
                    '(`image_data_format="channels_first"`). '
                    "For best performance, set "
                    '`image_data_format="channels_last"` in '
                    "your Keras config "
                    "at ~/.keras/keras.json."
                )
    return model

# %%
"""Train SqueezeNet-v1.1 model."""
# from keras.applications import Xception
# from keras.applications.xception import preprocess_input
# from keras.models import load_model
# import tensorflow as tf

# from keras.applications import MobileNetV2
# from keras.applications.mobilenet_v2 import preprocess_input
# from keras.models import load_model
# import tensorflow as tf

from keras.applications.imagenet_utils import preprocess_input
from keras.models import load_model
import tensorflow as tf

def train_chesspiece_model(num_of_epochs, batch_size, use_multiprocessing, lr):
    """Train the chess-piece model based on SqueezeNet-v1.1."""
    print("Initial training begins here...")

    # base_model = SqueezeNet(
    #     input_shape=(227, 227, 3), include_top=False, weights="imagenet"
    # )

    model = load_model("./models/SqueezeNet1p1_old.h5")

    # First train only blocks 7-9

    train_generator, validation_generator = data_generators(
        preprocess_input, (227, 227), batch_size
    )

    print(train_generator.class_indices)

    for layer in model.layers[:41]:
        layer.trainable = False
    for layer in model.layers[41:]:
        layer.trainable = True

    model.compile(
        optimizer="Adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )

    # callbacks = model_callbacks(20, "./models/Xception.h5", 0.2, 8)
    callbacks = model_callbacks(20, "./models/SqueezeNet1p1.h5", 0.2, 8)

    history = train_model(
        model,
        num_of_epochs,
        train_generator,
        validation_generator,
        callbacks,
        use_weights=False,
        workers = 5,
        use_multiprocessing = use_multiprocessing,
    )

    plot_model_history(
        history,
        "./models/SqueezeNet1p1_acc.png",
        "./models/SqueezeNet1p1_loss.png",
    )
    evaluate_model(model, validation_generator)

    model.save("./models/SqueezeNet1p1_last.h5")

    print("Initial training is complete!\n")


def continue_training(num_of_epochs, batch_size, use_multiprocessing, lr):
    """Continue training chess-piece model based on SqueezeNet-v1.1."""
    print("Global training begins here...")

    # model = load_model("./models/SqueezeNet1p1.h5")

    model = load_model("./models/SqueezeNet1p1_last.h5")

    # train_generator, validation_generator = data_generators(
    #     preprocess_input, (227, 227), 64
    # )

    train_generator, validation_generator = data_generators(
        preprocess_input, (227, 227), batch_size
    )

    print(train_generator.class_indices)

    # Train all layers
    for layer in model.layers:
        layer.trainable = True

    model.compile(
        optimizer="Adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )

    callbacks = model_callbacks(20, "./models/SqueezeNet1p1_all.h5", 0.2, 8)

    # history = train_model(
    #     model,
    #     100,
    #     train_generator,
    #     validation_generator,
    #     callbacks,
    #     use_weights=False,
    #     workers=5,
    # )

    history = train_model(
        model,
        num_of_epochs,
        train_generator,
        validation_generator,
        callbacks,
        use_weights=False,
        workers = 5,
        use_multiprocessing = use_multiprocessing,
    )

    plot_model_history(
        history,
        "./models/SqueezeNet1p1_all_acc.png",
        "./models/SqueezeNet1p1_all_loss.png",
    )
    evaluate_model(model, validation_generator)

    model.save("./models/SqueezeNet1p1_all_last.h5")

    print("Global training is complete!")

# %% [markdown]
# # Step 8: train the model!
#
# ### The final model "SqueezeNet1p1_all_last.h5" is in "./models"

# %%
num_of_epochs_for_initial_training = 20
num_of_epochs_for_continued_training = 100
batch_size = 16
use_multiprocessing = False
initial_learning_rate = 1e-5
global_learning_rate = 1e-5
train_chesspiece_model(num_of_epochs_for_initial_training, batch_size, use_multiprocessing, initial_learning_rate)
continue_training(num_of_epochs_for_continued_training, batch_size, use_multiprocessing, global_learning_rate)
# Out:
# Initial training begins here...
# Found 12885 images belonging to 13 classes.
# Found 3214 images belonging to 13 classes.
# {'B': 0, 'K': 1, 'N': 2, 'P': 3, 'Q': 4, 'R': 5, '_': 6, 'b': 7, 'k': 8, 'n': 9, 'p': 10, 'q': 11, 'r': 12}
# Epoch 1/20
#
# Epoch 1: val_accuracy improved from -inf to 0.84844, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 71s - loss: 1.1845 - accuracy: 0.8147 - val_loss: 0.6679 - val_accuracy: 0.8484 - lr: 1.0000e-05 - 71s/epoch - 88ms/step
# Epoch 2/20
#
# Epoch 2: val_accuracy improved from 0.84844 to 0.87844, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 55s - loss: 0.5180 - accuracy: 0.8715 - val_loss: 0.4558 - val_accuracy: 0.8784 - lr: 1.0000e-05 - 55s/epoch - 68ms/step
# Epoch 3/20
#
# Epoch 3: val_accuracy improved from 0.87844 to 0.90125, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 50s - loss: 0.3613 - accuracy: 0.8955 - val_loss: 0.3440 - val_accuracy: 0.9013 - lr: 1.0000e-05 - 50s/epoch - 62ms/step
# Epoch 4/20
#
# Epoch 4: val_accuracy improved from 0.90125 to 0.91469, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 50s - loss: 0.2687 - accuracy: 0.9165 - val_loss: 0.2714 - val_accuracy: 0.9147 - lr: 1.0000e-05 - 50s/epoch - 62ms/step
# Epoch 5/20
#
# Epoch 5: val_accuracy improved from 0.91469 to 0.93375, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 49s - loss: 0.2077 - accuracy: 0.9354 - val_loss: 0.2206 - val_accuracy: 0.9337 - lr: 1.0000e-05 - 49s/epoch - 61ms/step
# Epoch 6/20
#
# Epoch 6: val_accuracy improved from 0.93375 to 0.94219, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 54s - loss: 0.1634 - accuracy: 0.9486 - val_loss: 0.1857 - val_accuracy: 0.9422 - lr: 1.0000e-05 - 54s/epoch - 67ms/step
# Epoch 7/20
#
# Epoch 7: val_accuracy improved from 0.94219 to 0.95031, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 49s - loss: 0.1309 - accuracy: 0.9583 - val_loss: 0.1575 - val_accuracy: 0.9503 - lr: 1.0000e-05 - 49s/epoch - 61ms/step
# Epoch 8/20
#
# Epoch 8: val_accuracy improved from 0.95031 to 0.95781, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 55s - loss: 0.1060 - accuracy: 0.9669 - val_loss: 0.1359 - val_accuracy: 0.9578 - lr: 1.0000e-05 - 55s/epoch - 68ms/step
# Epoch 9/20
#
# Epoch 9: val_accuracy improved from 0.95781 to 0.96188, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 55s - loss: 0.0859 - accuracy: 0.9737 - val_loss: 0.1165 - val_accuracy: 0.9619 - lr: 1.0000e-05 - 55s/epoch - 68ms/step
# Epoch 10/20
#
# Epoch 10: val_accuracy improved from 0.96188 to 0.96781, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 54s - loss: 0.0697 - accuracy: 0.9800 - val_loss: 0.1035 - val_accuracy: 0.9678 - lr: 1.0000e-05 - 54s/epoch - 67ms/step
# Epoch 11/20
#
# Epoch 11: val_accuracy improved from 0.96781 to 0.97219, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 54s - loss: 0.0566 - accuracy: 0.9844 - val_loss: 0.0925 - val_accuracy: 0.9722 - lr: 1.0000e-05 - 54s/epoch - 67ms/step
# Epoch 12/20
#
# Epoch 12: val_accuracy improved from 0.97219 to 0.97469, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 56s - loss: 0.0463 - accuracy: 0.9883 - val_loss: 0.0812 - val_accuracy: 0.9747 - lr: 1.0000e-05 - 56s/epoch - 69ms/step
# Epoch 13/20
#
# Epoch 13: val_accuracy improved from 0.97469 to 0.97812, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 49s - loss: 0.0376 - accuracy: 0.9919 - val_loss: 0.0750 - val_accuracy: 0.9781 - lr: 1.0000e-05 - 49s/epoch - 61ms/step
# Epoch 14/20
#
# Epoch 14: val_accuracy improved from 0.97812 to 0.98062, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 54s - loss: 0.0308 - accuracy: 0.9939 - val_loss: 0.0657 - val_accuracy: 0.9806 - lr: 1.0000e-05 - 54s/epoch - 67ms/step
# Epoch 15/20
#
# Epoch 15: val_accuracy improved from 0.98062 to 0.98219, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 55s - loss: 0.0254 - accuracy: 0.9953 - val_loss: 0.0612 - val_accuracy: 0.9822 - lr: 1.0000e-05 - 55s/epoch - 68ms/step
# Epoch 16/20
#
# Epoch 16: val_accuracy improved from 0.98219 to 0.98250, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 56s - loss: 0.0207 - accuracy: 0.9966 - val_loss: 0.0558 - val_accuracy: 0.9825 - lr: 1.0000e-05 - 56s/epoch - 69ms/step
# Epoch 17/20
#
# Epoch 17: val_accuracy improved from 0.98250 to 0.98469, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 50s - loss: 0.0168 - accuracy: 0.9975 - val_loss: 0.0526 - val_accuracy: 0.9847 - lr: 1.0000e-05 - 50s/epoch - 62ms/step
# Epoch 18/20
#
# Epoch 18: val_accuracy did not improve from 0.98469
# 805/805 - 54s - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.0498 - val_accuracy: 0.9847 - lr: 1.0000e-05 - 54s/epoch - 67ms/step
# Epoch 19/20
#
# Epoch 19: val_accuracy improved from 0.98469 to 0.98500, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 56s - loss: 0.0111 - accuracy: 0.9988 - val_loss: 0.0478 - val_accuracy: 0.9850 - lr: 1.0000e-05 - 56s/epoch - 69ms/step
# Epoch 20/20
#
# Epoch 20: val_accuracy improved from 0.98500 to 0.98656, saving model to ./models/SqueezeNet1p1.h5
# 805/805 - 50s - loss: 0.0090 - accuracy: 0.9990 - val_loss: 0.0452 - val_accuracy: 0.9866 - lr: 1.0000e-05 - 50s/epoch - 63ms/step
# 201/201 [==============================] - 13s 62ms/step - loss: 0.0450 - accuracy: 0.9866
# Test loss: 0.0449972040951252
# Test accuracy: 0.9866210222244263
# Initial training is complete!
#
# Global training begins here...
# Found 12885 images belonging to 13 classes.
# Found 3214 images belonging to 13 classes.
# {'B': 0, 'K': 1, 'N': 2, 'P': 3, 'Q': 4, 'R': 5, '_': 6, 'b': 7, 'k': 8, 'n': 9, 'p': 10, 'q': 11, 'r': 12}
# Epoch 1/100
#
# Epoch 1: val_accuracy improved from -inf to 0.98719, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 68s - loss: 0.0098 - accuracy: 0.9985 - val_loss: 0.0383 - val_accuracy: 0.9872 - lr: 1.0000e-05 - 68s/epoch - 84ms/step
# Epoch 2/100
#
# Epoch 2: val_accuracy improved from 0.98719 to 0.99031, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 57s - loss: 0.0053 - accuracy: 0.9998 - val_loss: 0.0357 - val_accuracy: 0.9903 - lr: 1.0000e-05 - 57s/epoch - 71ms/step
# Epoch 3/100
#
# Epoch 3: val_accuracy did not improve from 0.99031
# 805/805 - 58s - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.0312 - val_accuracy: 0.9903 - lr: 1.0000e-05 - 58s/epoch - 72ms/step
# Epoch 4/100
#
# Epoch 4: val_accuracy did not improve from 0.99031
# 805/805 - 53s - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0411 - val_accuracy: 0.9872 - lr: 1.0000e-05 - 53s/epoch - 66ms/step
# Epoch 5/100
#
# Epoch 5: val_accuracy did not improve from 0.99031
# 805/805 - 52s - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0373 - val_accuracy: 0.9900 - lr: 1.0000e-05 - 52s/epoch - 65ms/step
# Epoch 6/100
#
# Epoch 6: val_accuracy improved from 0.99031 to 0.99156, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 57s - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0302 - val_accuracy: 0.9916 - lr: 1.0000e-05 - 57s/epoch - 71ms/step
# Epoch 7/100
#
# Epoch 7: val_accuracy improved from 0.99156 to 0.99250, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 58s - loss: 7.9849e-04 - accuracy: 0.9998 - val_loss: 0.0289 - val_accuracy: 0.9925 - lr: 1.0000e-05 - 58s/epoch - 72ms/step
# Epoch 8/100
#
# Epoch 8: val_accuracy improved from 0.99250 to 0.99375, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 57s - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0259 - val_accuracy: 0.9937 - lr: 1.0000e-05 - 57s/epoch - 70ms/step
# Epoch 9/100
#
# Epoch 9: val_accuracy did not improve from 0.99375
# 805/805 - 57s - loss: 8.1167e-04 - accuracy: 0.9999 - val_loss: 0.0240 - val_accuracy: 0.9937 - lr: 1.0000e-05 - 57s/epoch - 70ms/step
# Epoch 10/100
#
# Epoch 10: val_accuracy did not improve from 0.99375
# 805/805 - 55s - loss: 4.8587e-04 - accuracy: 0.9999 - val_loss: 0.0233 - val_accuracy: 0.9934 - lr: 1.0000e-05 - 55s/epoch - 68ms/step
# Epoch 11/100
#
# Epoch 11: val_accuracy did not improve from 0.99375
# 805/805 - 56s - loss: 2.8798e-04 - accuracy: 0.9999 - val_loss: 0.0229 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 56s/epoch - 70ms/step
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.99375
# 805/805 - 53s - loss: 2.2776e-04 - accuracy: 0.9999 - val_loss: 0.0241 - val_accuracy: 0.9937 - lr: 1.0000e-05 - 53s/epoch - 66ms/step
# Epoch 13/100
#
# Epoch 13: val_accuracy did not improve from 0.99375
# 805/805 - 57s - loss: 4.2434e-04 - accuracy: 0.9998 - val_loss: 0.0273 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 57s/epoch - 71ms/step
# Epoch 14/100
#
# Epoch 14: val_accuracy did not improve from 0.99375
# 805/805 - 57s - loss: 3.7366e-04 - accuracy: 0.9999 - val_loss: 0.0245 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 57s/epoch - 71ms/step
# Epoch 15/100
#
# Epoch 15: val_accuracy did not improve from 0.99375
# 805/805 - 56s - loss: 7.6165e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9934 - lr: 1.0000e-05 - 56s/epoch - 70ms/step
# Epoch 16/100
#
# Epoch 16: val_accuracy did not improve from 0.99375
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 805/805 - 57s - loss: 5.0793e-05 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9934 - lr: 1.0000e-05 - 57s/epoch - 71ms/step
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.99375
# 805/805 - 56s - loss: 3.6754e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9934 - lr: 2.0000e-06 - 56s/epoch - 70ms/step
# Epoch 18/100
#
# Epoch 18: val_accuracy did not improve from 0.99375
# 805/805 - 58s - loss: 3.3398e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9931 - lr: 2.0000e-06 - 58s/epoch - 72ms/step
# Epoch 19/100
#
# Epoch 19: val_accuracy did not improve from 0.99375
# 805/805 - 57s - loss: 3.0103e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9931 - lr: 2.0000e-06 - 57s/epoch - 70ms/step
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.99375
# 805/805 - 56s - loss: 2.6447e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9934 - lr: 2.0000e-06 - 56s/epoch - 70ms/step
# Epoch 21/100
#
# Epoch 21: val_accuracy did not improve from 0.99375
# 805/805 - 58s - loss: 2.2502e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9934 - lr: 2.0000e-06 - 58s/epoch - 72ms/step
# Epoch 22/100
#
# Epoch 22: val_accuracy did not improve from 0.99375
# 805/805 - 54s - loss: 1.9049e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9934 - lr: 2.0000e-06 - 54s/epoch - 67ms/step
# Epoch 23/100
#
# Epoch 23: val_accuracy did not improve from 0.99375
# 805/805 - 57s - loss: 1.5475e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9937 - lr: 2.0000e-06 - 57s/epoch - 71ms/step
# Epoch 24/100
#
# Epoch 24: val_accuracy improved from 0.99375 to 0.99437, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 57s - loss: 1.2597e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9944 - lr: 2.0000e-06 - 57s/epoch - 71ms/step
# Epoch 25/100
#
# Epoch 25: val_accuracy improved from 0.99437 to 0.99469, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 57s - loss: 9.6010e-06 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9947 - lr: 2.0000e-06 - 57s/epoch - 71ms/step
# Epoch 26/100
#
# Epoch 26: val_accuracy improved from 0.99469 to 0.99500, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 52s - loss: 7.3182e-06 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9950 - lr: 2.0000e-06 - 52s/epoch - 65ms/step
# Epoch 27/100
#
# Epoch 27: val_accuracy did not improve from 0.99500
# 805/805 - 57s - loss: 5.5619e-06 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9950 - lr: 2.0000e-06 - 57s/epoch - 71ms/step
# Epoch 28/100
#
# Epoch 28: val_accuracy improved from 0.99500 to 0.99563, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 56s - loss: 4.1124e-06 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9956 - lr: 2.0000e-06 - 56s/epoch - 70ms/step
# Epoch 29/100
#
# Epoch 29: val_accuracy did not improve from 0.99563
# 805/805 - 52s - loss: 2.9135e-06 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9953 - lr: 2.0000e-06 - 52s/epoch - 65ms/step
# Epoch 30/100
#
# Epoch 30: val_accuracy improved from 0.99563 to 0.99594, saving model to ./models/SqueezeNet1p1_all.h5
# 805/805 - 59s - loss: 2.1519e-06 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9959 - lr: 2.0000e-06 - 59s/epoch - 73ms/step
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.99594
# 805/805 - 52s - loss: 1.5474e-06 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9953 - lr: 2.0000e-06 - 52s/epoch - 65ms/step
# Epoch 32/100
#
# Epoch 32: val_accuracy did not improve from 0.99594
# 805/805 - 53s - loss: 8.8068e-07 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9956 - lr: 2.0000e-06 - 53s/epoch - 65ms/step
# Epoch 33/100
#
# Epoch 33: val_accuracy did not improve from 0.99594
# 805/805 - 52s - loss: 9.7021e-07 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9956 - lr: 2.0000e-06 - 52s/epoch - 64ms/step
# Epoch 34/100
#
# Epoch 34: val_accuracy did not improve from 0.99594
# 805/805 - 58s - loss: 6.8222e-07 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9959 - lr: 2.0000e-06 - 58s/epoch - 72ms/step
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.99594
# 805/805 - 52s - loss: 4.2557e-07 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9959 - lr: 2.0000e-06 - 52s/epoch - 65ms/step
# Epoch 36/100
#
# Epoch 36: val_accuracy did not improve from 0.99594
# 805/805 - 56s - loss: 3.2712e-07 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9956 - lr: 2.0000e-06 - 56s/epoch - 70ms/step
# Epoch 37/100
#
# Epoch 37: val_accuracy did not improve from 0.99594
# 805/805 - 58s - loss: 2.4016e-07 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9956 - lr: 2.0000e-06 - 58s/epoch - 72ms/step
# Epoch 38/100
#
# Epoch 38: val_accuracy did not improve from 0.99594
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 805/805 - 60s - loss: 1.7871e-07 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9956 - lr: 2.0000e-06 - 60s/epoch - 75ms/step
# Epoch 39/100
#
# Epoch 39: val_accuracy did not improve from 0.99594
# 805/805 - 57s - loss: 1.3208e-07 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9956 - lr: 4.0000e-07 - 57s/epoch - 71ms/step
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.99594
# 805/805 - 57s - loss: 1.2172e-07 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9956 - lr: 4.0000e-07 - 57s/epoch - 70ms/step
# Epoch 41/100
#
# Epoch 41: val_accuracy did not improve from 0.99594
# 805/805 - 57s - loss: 1.1374e-07 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9959 - lr: 4.0000e-07 - 57s/epoch - 71ms/step
# Epoch 42/100
#
# Epoch 42: val_accuracy did not improve from 0.99594
# 805/805 - 59s - loss: 1.0571e-07 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9959 - lr: 4.0000e-07 - 59s/epoch - 74ms/step
# Epoch 43/100
#
# Epoch 43: val_accuracy did not improve from 0.99594
# 805/805 - 56s - loss: 9.7421e-08 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9956 - lr: 4.0000e-07 - 56s/epoch - 70ms/step
# Epoch 44/100
#
# Epoch 44: val_accuracy did not improve from 0.99594
# 805/805 - 52s - loss: 8.9668e-08 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9959 - lr: 4.0000e-07 - 52s/epoch - 64ms/step
# Epoch 45/100
# Restoring model weights from the end of the best epoch: 25.
#
# Epoch 45: val_accuracy did not improve from 0.99594
# 805/805 - 51s - loss: 8.3156e-08 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9956 - lr: 4.0000e-07 - 51s/epoch - 64ms/step
# Epoch 45: early stopping
# 201/201 [==============================] - 12s 60ms/step - loss: 0.0232 - accuracy: 0.9947
# Test loss: 0.023188430815935135
# Test accuracy: 0.9947106242179871
# Global training is complete!

# %% [markdown]
# # Step 9: convert the model from keras to onnx

# %%
# !pip install tf2onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tf2onnx
#   Downloading tf2onnx-1.14.0-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.9/dist-packages (from tf2onnx) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from tf2onnx) (1.16.0)
# Collecting onnx>=1.4.1
#   Downloading onnx-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 80.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from tf2onnx) (2.27.1)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: protobuf<4,>=3.20.2 in /usr/local/lib/python3.9/dist-packages (from onnx>=1.4.1->tf2onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.9/dist-packages (from onnx>=1.4.1->tf2onnx) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->tf2onnx) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->tf2onnx) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->tf2onnx) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->tf2onnx) (3.4)
# Installing collected packages: flatbuffers, onnx, tf2onnx
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.3.3
#     Uninstalling flatbuffers-23.3.3:
#       Successfully uninstalled flatbuffers-23.3.3
# Successfully installed flatbuffers-2.0.7 onnx-1.13.1 tf2onnx-1.14.0

# %%
import tf2onnx

MODELS_PATH = "./models/"
KERAS_MODEL_NAME = "SqueezeNet1p1_all_last.h5"
ONNX_MODEL_NAME = KERAS_MODEL_NAME[:-2] + "onnx"

image_size = 227
# image_size = 299
channels = 3
batch_size = 1
target_opset = 13

# Convert the .h5 keras model to .pb
keras_model = tf.keras.models.load_model(MODELS_PATH + KERAS_MODEL_NAME)
keras_model.save(MODELS_PATH + "saved_model")

# Convert to ONNX
spec = (
        tf.TensorSpec(
            (batch_size, image_size, image_size, channels),
            tf.float32,
            name="input",
        ),
    )
model_proto, _ = tf2onnx.convert.from_keras(
    keras_model,
    input_signature=spec,
    opset=target_opset,
    output_path=MODELS_PATH + ONNX_MODEL_NAME,
)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 26). These functions will not be directly callable after loading.
